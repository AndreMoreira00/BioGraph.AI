# %%
! pip install pandas
! pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_path = "../Rfam/Rfam.pdb"

column_names = [
    'rfam_acc', 
    'pdb_id', 
    'chain', 
    'pdb_start', 
    'pdb_end', 
    'bit_score', 
    'evalue_score', 
    'cm_start', 
    'cm_end', 
    'hex_colour'
]

data = pd.read_csv(
  data_path, 
  sep='\s+',         
  header=1,      
  names=column_names, 
  comment='#'
)

print("DataFrame carregado com sucesso usando pd.read_csv!")
data.head()
# Out:
# DataFrame carregado com sucesso usando pd.read_csv!
#   rfam_acc pdb_id chain  pdb_start  pdb_end  bit_score  evalue_score  \
# 0  RF00001   3j8g     A          2      117       77.2  3.200000e-17
# 1  RF00001   4v64    BA          3      118       77.2  3.200000e-17
# 2  RF00001   5el5    1J          5      121      100.7  2.800000e-23
# 3  RF00001   6ftg     v          1      119      118.9  5.300000e-28
# 4  RF00001   6ri5     x          1      121       88.8  3.300000e-20
#
#    cm_start  cm_end hex_colour
# 0         1     119     c0af92
# 1         1     119     c0af92
# 2         1     119     c0af92
# 3         1     119     c0af92
# 4         1     119     c0af92
